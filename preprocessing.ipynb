# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
df=pd.read_csv("C:\\Users\\Gian\\OneDrive - LUISS Libera Università Internazionale degli Studi Sociali Guido Carli\\ML\\Final Project\\Weekly series\\Amazon_weekly.csv")

# %%
df.head(10)
# Out:
#          Date    Open     High      Low   Close   Volume
# 0  1997-05-18  18.000  30.0000  18.0000  1.7292  7238000
# 1  1997-05-25  21.125  21.2500  15.7500  1.5000  4836500
# 2  1997-06-01  18.125  19.7500  17.5000  1.5000  1611600
# 3  1997-06-08  18.125  20.5000  16.5000  1.6563  1527900
# 4  1997-06-15  19.875  20.5000  18.3750  1.5834   943700
# 5  1997-06-22  19.250  19.2500  17.9375  1.5261  1039600
# 6  1997-06-29  18.500  18.5000  17.7500  1.4896   690200
# 7  1997-07-06  18.125  23.0000  17.7500  1.9115  1708200
# 8  1997-07-13  22.000  30.8750  22.0000  2.2917  4284600
# 9  1997-07-20  27.875  29.9375  25.3750  2.1563  1736800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1399 entries, 0 to 1398
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1399 non-null   object
#  1   Open    1399 non-null   float64
#  2   High    1399 non-null   float64
#  3   Low     1399 non-null   float64
#  4   Close   1399 non-null   float64
#  5   Volume  1399 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 65.7+ KB

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1399 entries, 0 to 1398
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1399 non-null   datetime64[ns]
#  1   Open    1399 non-null   float64
#  2   High    1399 non-null   float64
#  3   Low     1399 non-null   float64
#  4   Close   1399 non-null   float64
#  5   Volume  1399 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 65.7 KB

# %%
df.head(10)
# Out:
#         Date    Open     High      Low   Close   Volume
# 0 1997-05-18  18.000  30.0000  18.0000  1.7292  7238000
# 1 1997-05-25  21.125  21.2500  15.7500  1.5000  4836500
# 2 1997-06-01  18.125  19.7500  17.5000  1.5000  1611600
# 3 1997-06-08  18.125  20.5000  16.5000  1.6563  1527900
# 4 1997-06-15  19.875  20.5000  18.3750  1.5834   943700
# 5 1997-06-22  19.250  19.2500  17.9375  1.5261  1039600
# 6 1997-06-29  18.500  18.5000  17.7500  1.4896   690200
# 7 1997-07-06  18.125  23.0000  17.7500  1.9115  1708200
# 8 1997-07-13  22.000  30.8750  22.0000  2.2917  4284600
# 9 1997-07-20  27.875  29.9375  25.3750  2.1563  1736800

# %%
plt.plot(df['Date'], df['Close'])
plt.plot(df['Date'], df['Low'])
plt.xlabel('Date (weekly)')
plt.ylabel('Price (close, USD)')
plt.grid(True)
# plt.savefig("amazon.png")

# %% [markdown]
# Amazon splits:
# - 1998-06-02 2:1
# - 1999-01-05 3:1
# - 1999-09-05 2:1
# - 2022-06-06 20:1

# %%
filtered_df = df[(df['Date'] > pd.to_datetime("1998-04-26")) & (df['Date'] < pd.to_datetime("1998-12-12"))]

plt.plot(filtered_df['Date'], filtered_df['Close'])
plt.xlabel('Date (weekly)')
plt.ylabel('Price (close, USD)')
plt.xticks(rotation=30)
plt.grid(True)
plt.show()

# %%
plt.plot(filtered_df['Date'], filtered_df['Volume'])
plt.xlabel('Date (weekly)')
plt.ylabel('Volume')
plt.xticks(rotation=30)
plt.grid(True)
plt.show()

# %%
filtered_df
# Out:
#            Date       Open       High        Low      Close     Volume
# 1294 2022-03-06  3048.5000  3088.9800  2876.1399  2912.8201   13731778
# 1295 2022-03-13  2908.8701  2993.5000  2671.7749  2910.4900   23230701
# 1296 2022-03-20  2919.6201  3231.8799  2817.6799  3225.0100   20113827
# 1297 2022-03-27  3222.4199  3326.5249  3191.0601  3295.4700   14607772
# 1298 2022-04-03  3299.5000  3416.6299  3246.3899  3271.2000   14956843
# 1299 2022-04-10  3282.5000  3367.8899  3084.6201  3089.2100   14834014
# 1300 2022-04-17  3054.2600  3120.5000  2992.0000  3034.1299   10593300
# 1301 2022-04-24  3030.4700  3172.9800  2873.9500  2887.0000   14877651
# 1302 2022-05-01  2880.4600  2924.4299  2432.5000  2485.6299   29013222
# 1303 2022-05-08  2448.0200  2524.4099  2261.6299  2295.4500   30352697
# 1304 2022-05-15  2226.2500  2280.0000  2048.8201  2261.1001   28168192
# 1305 2022-05-22  2262.0000  2316.0000  2100.1899  2151.8201   22196919
# ...

# %%
df[df['Close']<df['Low']]
# Out:
#           Date      Open      High      Low    Close    Volume
# 0   1997-05-18   18.0000   30.0000   18.000   1.7292   7238000
# 1   1997-05-25   21.1250   21.2500   15.750   1.5000   4836500
# 2   1997-06-01   18.1250   19.7500   17.500   1.5000   1611600
# 3   1997-06-08   18.1250   20.5000   16.500   1.6563   1527900
# 4   1997-06-15   19.8750   20.5000   18.375   1.5834    943700
# ..         ...       ...       ...      ...      ...       ...
# 115 1999-08-01  110.4375  115.5000   97.500  50.0313  55493000
# 116 1999-08-08   98.3750  102.1250   82.000  44.7813  63627000
# 117 1999-08-15   91.5000   97.4375   82.000  48.7188  42908500
# 118 1999-08-22   98.2500  117.5000   95.500  56.7188  48701800
# 119 1999-08-29  115.9375  135.5625  115.750  64.2500  48662200
#
# [120 rows x 6 columns]

# %%
df[df['Close']>df['High']]
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume]
# Index: []

# %% [markdown]
# ***

# %%
df_ibm=pd.read_csv("C:\\Users\\Gian\\OneDrive - LUISS Libera Università Internazionale degli Studi Sociali Guido Carli\\ML\\Final Project\\Weekly series\\IBM_weekly.csv")

# %%
df_ibm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1566 entries, 0 to 1565
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1566 non-null   object
#  1   Open    1566 non-null   float64
#  2   High    1566 non-null   float64
#  3   Low     1566 non-null   float64
#  4   Close   1566 non-null   float64
#  5   Volume  1566 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 73.5+ KB

# %%
df_ibm['Date']=pd.to_datetime(df_ibm['Date'])

# %%
plt.plot(df_ibm['Date'], df_ibm['Close'], color='Blue')
plt.plot(df_ibm['Date'], df_ibm['Low'], color='Red')
plt.xlabel('Date (weekly)')
plt.ylabel('Price (close, USD)')
plt.grid(True)

# %%
df_ibm[df_ibm['Close']<df_ibm['Low']]
# Out:
#            Date     Open     High      Low     Close    Volume
# 0    1994-03-06   53.125   53.875   52.125    8.0537   9055900
# 1    1994-03-13   53.000   56.250   51.375    8.5512  14884100
# 2    1994-03-20   56.125   58.375   55.875    8.7424  12402200
# 3    1994-03-27   56.875   58.875   53.625    8.2642  12237600
# 4    1994-04-03   54.375   55.000   52.000    8.3599  14114100
# ...         ...      ...      ...      ...       ...       ...
# 1543 2023-10-01  146.570  147.430  139.610  137.4734  23445500
# 1544 2023-10-08  140.040  142.940  139.860  139.1685  15932300
# 1545 2023-10-15  142.300  143.420  138.270  135.6704  16385600
# 1546 2023-10-22  139.280  140.620  136.310  134.3966  21043800
# 1557 2024-01-07  162.830  163.290  158.670  157.7221  15322500
#
# [1370 rows x 6 columns]
